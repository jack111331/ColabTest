# %% [markdown]
# <a href="https://colab.research.google.com/github/jack111331/ColabTest/blob/main/Disco/DisCo_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py310_23.9.0-0-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py310" --user
# Out:
# --2026-01-21 05:47:42--  https://repo.anaconda.com/miniconda/Miniconda3-py310_23.9.0-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113367569 (108M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>] 108.12M   135MB/s    in 0.8s
#
# 2026-01-21 05:47:43 (135 MB/s) - ‘mini.sh’ saved [113367569/113367569]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
# ...

# %%
# !python --version
# Out:
# Python 3.10.13

# %% [markdown]
# ### 1. Clone the github repo

# %%
# !git clone https://github.com/Wangt-CN/DisCo
# Out:
# Cloning into 'DisCo'...
# remote: Enumerating objects: 870, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 870 (delta 72), reused 63 (delta 55), pack-reused 743 (from 1)
# Receiving objects: 100% (870/870), 98.36 MiB | 41.67 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %% [markdown]
# ### 2. Install the package
#
# Ps: Most errors are due to the unsuccessful package installation, please check the installation carefully.

# %%
# !pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchtext==0.14.1 torchaudio==0.13.1 torchdata==0.5.1 xformers deepspeed==0.6.3 einops --extra-index-url https://download.pytorch.org/whl/cu117
# !pip install --user progressbar psutil pymongo simplejson yacs boto3 pyyaml ete3 easydict deprecated future django orderedset python-magic datasets h5py omegaconf einops ipdb transformers huggingface_hub tensorboardX hjson wandb deprecated diffusers==0.14.0 gradio colorlog deepdish configobj json_lines
# !pip install --user --exists-action w -r DisCo/requirements.txt
# !pip install git+https://github.com/microsoft/azfuse.git

# %%
# !pip install --upgrade pip==24.0
# Out:
# ...
#   Obtaining dependency information for pip==24.0 from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 59.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# ...

# %%
# !apt install build-essential
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !conda install cudatoolkit=11.7 cuda-toolkit=11.7.1 -c nvidia -y
# Out:
# done
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# done
# |

# %%
# !ls ../../usr/local
# Out:
# bin		 cuda-12	   lib		sbin
# cmake		 cuda-12.5	   libexec	share
# colab		 dist_metrics.pxd  LICENSE.md	shell
# compiler_compat  envs		   LICENSE.txt	src
# condabin	 etc		   man		ssl
# conda-meta	 games		   opt		x86_64-conda_cos7-linux-gnu
# cuda		 include	   pkgs		x86_64-conda-linux-gnu

# %%
# !ls ../../usr/local/pkgs/cudatoolkit-11.7.0-hd8887f6_10/info
# !../../usr/local/cuda/bin/nvcc --version
# !conda info --env
# Out:
# about.json  git		     index.json  paths.json  repodata_record.json
# files	    hash_input.json  licenses	 recipe      test
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# # conda environments:
# #
# base                     /usr/local

# %%
# !conda env config vars set CUDA_HOME="$CONDA_PREFIX"
# !echo $CONDA_PREFIX
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !pip install --user --exists-action w --verbose -r requirements.txt
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   /usr/local/lib/python3.10/site-packages/setuptools/command/build_py.py:201: _Warning: Package 'deepspeed.ops.csrc.adagrad' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !pip install --user --exists-action w --verbose xformers==0.0.12
# Out:
# Using pip 24.0 from /usr/local/lib/python3.10/site-packages/pip (python 3.10)
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ERROR: Could not find a version that satisfies the requirement xformers==0.0.12 (from versions: 0.0.22.post3, 0.0.22.post4)
# ERROR: No matching distribution found for xformers==0.0.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/DisCo/
# !cp /content/drive/MyDrive/DisCo/mp_rank_00_model_states.pt .
# Out:
# mp_rank_00_model_states.pt

# %%
drive.flush_and_unmount()

# %% [markdown]
# ### 3. Download the pretrained model
# Feel free to use our other [checkpoints](https://github.com/Wangt-CN/DisCo#model-checkpoint-google-cloud-tiktok-training-data-fid-fvd-188--more-tiktok-style-training-data-fid-fvd-157) or change to your own model

# %%
# !git clone https://huggingface.co/lambdalabs/sd-image-variations-diffusers
# !wget https://storage.googleapis.com/disco-checkpoint-share/checkpoint_ft/moretiktok_nocfg/mp_rank_00_model_states.pt
# Out:
# Cloning into 'sd-image-variations-diffusers'...
# remote: Enumerating objects: 98, done.
# remote: Total 98 (delta 0), reused 0 (delta 0), pack-reused 98 (from 1)
# Unpacking objects: 100% (98/98), 1.57 MiB | 6.12 MiB/s, done.
# Filtering content: 100% (4/4), 5.77 GiB | 53.84 MiB/s, done.
# --2026-01-21 03:54:00--  https://storage.googleapis.com/disco-checkpoint-share/checkpoint_ft/moretiktok_nocfg/mp_rank_00_model_states.pt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.137.207, 142.250.101.207, 142.250.141.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.137.207|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-21 03:54:00 ERROR 403: Forbidden.

# %% [markdown]
# ### 4. Start Running

# %%
import os
os.chdir('/content/DisCo')
os.getcwd()
# Out:
# '/content/DisCo'

# %%
# !pip uninstall colorlog -y
# !pip uninstall deepdish -y
# !pip uninstall configobj -y
# !pip uninstall json_lines -y
# !pip install colorlog deepdish configobj json_lines

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### 5. Launch the gradio demo

# %%
# !pip install numpy==1.24 imageio
# Out:
# ...
#   Obtaining dependency information for imageio from https://files.pythonhosted.org/packages/fb/fe/301e0936b79bcab4cacc7548bf2853fc28dced0a578bab1f7ef53c9aa75b/imageio-2.37.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.6/317.6 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# aiofiles                  24.1.0
# aiohappyeyeballs          2.6.1
# aiohttp                   3.13.3
# aiosignal                 1.4.0
# annotated-doc             0.0.4
# annotated-types           0.7.0
# antlr4-python3-runtime    4.9.3
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# asgiref                   3.11.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# async-timeout             5.0.1
# attrs                     25.4.0
# azfuse                    0.1
# azure-core                1.38.0
# azure-storage-blob        12.28.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    4.1.0
# blosc2                    3.12.2
# boltons                   23.0.0
# boto3                     1.42.31
# botocore                  1.42.31
# Bottleneck                1.6.0
# ...

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "/content/DisCo/main.py", line 5, in <module>
#     from utils.wutils_ldm import *
#   File "/content/DisCo/utils/wutils_ldm.py", line 51, in <module>
#     from torchvision import datasets, transforms, utils
# ModuleNotFoundError: No module named 'torchvision'
